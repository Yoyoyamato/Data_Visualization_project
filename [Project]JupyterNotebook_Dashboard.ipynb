# %% [markdown]
# ## Creating a Dashboard on Jupyter Notebook

# %% [markdown]
# ### About this project
# - This project's objective is to create a dashboard to satisfy the users needs
# - Here, I will be using the following libraries:
#     - pandas
#     - numpy
#     - matplotlib
#     - seaborn
#     -
# - I will also be commenting on places where you can change the variables to adjust to your needs
# - The sales data that I will be using is from https://www.kaggle.com/kyanyoga/sample-sales-data?select=sales_data_sample.csv
#
# #### Steps
# -  aaa
#
# |aaa|aaa|
# |:--|:--|
# |dddd|dddd|
# |dddd|dddd|
# |dddd|dddd|
# |...|...|
# |...|...|
# |...|...|
#
# -

# %% [markdown]
# ## All the importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## STEP 1
# #### Load the dataset that we are going to use; understand and clean the dataset if necessary

# %%
# since our data was not in a UTF-8 format, we had to see with format suits this case
encoding_list = ['ascii', 'big5', 'big5hkscs', 'cp037', 'cp273', 'cp424', 'cp437', 'cp500', 'cp720', 'cp737'
                 , 'cp775', 'cp850', 'cp852', 'cp855', 'cp856', 'cp857', 'cp858', 'cp860', 'cp861', 'cp862'
                 , 'cp863', 'cp864', 'cp865', 'cp866', 'cp869', 'cp874', 'cp875', 'cp932', 'cp949', 'cp950'
                 , 'cp1006', 'cp1026', 'cp1125', 'cp1140', 'cp1250', 'cp1251', 'cp1252', 'cp1253', 'cp1254'
                 , 'cp1255', 'cp1256', 'cp1257', 'cp1258', 'euc_jp', 'euc_jis_2004', 'euc_jisx0213', 'euc_kr'
                 , 'gb2312', 'gbk', 'gb18030', 'hz', 'iso2022_jp', 'iso2022_jp_1', 'iso2022_jp_2'
                 , 'iso2022_jp_2004', 'iso2022_jp_3', 'iso2022_jp_ext', 'iso2022_kr', 'latin_1', 'iso8859_2'
                 , 'iso8859_3', 'iso8859_4', 'iso8859_5', 'iso8859_6', 'iso8859_7', 'iso8859_8', 'iso8859_9'
                 , 'iso8859_10', 'iso8859_11', 'iso8859_13', 'iso8859_14', 'iso8859_15', 'iso8859_16', 'johab'
                 , 'koi8_r', 'koi8_t', 'koi8_u', 'kz1048', 'mac_cyrillic', 'mac_greek', 'mac_iceland', 'mac_latin2'
                 , 'mac_roman', 'mac_turkish', 'ptcp154', 'shift_jis', 'shift_jis_2004', 'shift_jisx0213', 'utf_32'
                 , 'utf_32_be', 'utf_32_le', 'utf_16', 'utf_16_be', 'utf_16_le', 'utf_7', 'utf_8', 'utf_8_sig']

for encoding in encoding_list:
    worked = True
    try:
        df = pd.read_csv("sales_data.csv", encoding=encoding, nrows=5)
    except:
        worked = False
    if worked:
        print(encoding, ':\n', df.head())
# Out:
# cp037 :
#    |êàáê+í(âáêéí +èñèß|êàáêáà&êñäáá äç|êàáê<ñ+á+í(âáêë <áë|êàáêà èáëè èíëéèê¬ñà(|+èç¬ñàßá ê¬ñà&ê|àíäè<ñ+á(ëê&&ê|àíäèä|àáäíëè|(áê+ (á&ç|+á ààêáëë<ñ+á ààêáëë<ñ+áäñèßëè èá&|ëè <ä|àáä|í+èêßèáêêñè|êßä|+è äè< ëè+ (áä|+è äèãñêëè+ (áàá <ëñ!á
# 0  ëÇÑøøÁÀ...
# 1  ëÇÑøøÁÀ...
# 2  ëÇÑøøÁ...
# 3  ëÇÑøøÁ...
# 4  ëÇÑøø...
# cp273 :
#    !êàáê+í(âáêéí +èñè~!êàáêáà&êñ{áá {ç!êàáê<ñ+á+í(âáêë <áë!êàáêà èáëè èíëéèê^ñà(!+èç^ñà~á ê^ñà&ê!àí{è<ñ+á(ëê&&ê!àí{è{!àá{íëè!(áê+ (á&ç!+á ààêáëë<ñ+á ààêáëë<ñ+á{ñè~ëè èá&!ëè <{!àá{!í+èê~èáêêñè!ê~{!+è {è< ëè+ (á{!+è {èãñêëè+ (áàá <ëñÜá
# 0  ëÇÑøøÁÀ...
# 1  ëÇÑøøÁÀ...
# 2  ëÇÑøøÁ...
# 3  ëÇÑøøÁ...
# ...

# %%
data = pd.read_csv("sales_data.csv", encoding = 'cp949')
data.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
### understanding 
# unique values for each of the categorical variables
# relevant columns for our analysis

### data cleaning
# find any NULL rows
# clean orderdate column

### what kind of analysis we want to do (what kind of metrics do we want for our dashboard)

# %% [markdown]
# ## STEP 2
# #### bbb

# %% [markdown]
# ## STEP 3
# #### ccc
